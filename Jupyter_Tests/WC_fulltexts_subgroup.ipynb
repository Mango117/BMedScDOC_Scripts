# %%
#Search for specific terms within a corpus of texts
#texts used are txt files of pubmed "Disorders of Consciousness" studies
#2239 documents considered relevant after TM (references already removed)
#Outputs: bar graph of all dictionary terms + BoW of corpus
#Outputs: term document matrix as a csv in downloads

# %%
import functions

# %%
dict_path = "/Users/manojarachige/Documents/Coding/BMedScDOC1/Assets/Inputs/CombinedDict.txt"
corpus_dir = "/Users/manojarachige/Documents/Coding/BMedScDOC1/Assets/TM_pdfs"
replacement_path = "/Users/manojarachige/Documents/Coding/BMedScDOC1/Assets/Inputs/CombinedDict.csv"

# %%
#define the lists we'll need for outputs

dictionary = []

combined = [] #For pathway 2 - total dictionary list

docs = []

# %%
doc_list = functions.os_level.get_corpus(corpus_dir, "txt")

# %%
print("We have a total of {} articles".format(len(doc_list)))
# Out:
# We have a total of 367 articles

# %%
dictionary = functions.os_level.makedict(dict_path)

# %%
def action(i, doc_list, dictionary):
    
    text = maketxt("{}".format(corpus_dir) + "/{}".format(doc_list[i]), replacement_path)
        
    #remove non-dictionary words
    text = rem_dict(dictionary,text) 
        
    #add to Total List for Combined BoW later
    combined.extend(text) 
        
    #check corpus doc again
        
    #add to list of text strings for tdm
    doc_for_tdm = " ".join(text)
    docs.append(doc_for_tdm)
    
    
    
#Create list of words appearing in txt file 
def maketxt(text, csv_path):
    string = ''
    with open(text) as file:
        string = file.read()
        return functions.processing.preprocess(string, csv_path)
    
#Remove words not in the dictionary NOTE: Will find words within words ie. bar within bars
def rem_dict(dictionary, doc):
    new_doc = []
    for i in range(len(doc)):
        for j in range(len(dictionary)):
            if dictionary[j] in doc[i]:
                new_doc.append(dictionary[j])
    return new_doc

# %%
for i in range(len(doc_list)):
            action(i, doc_list, dictionary)

# %%
save_location = "/Users/manojarachige/Downloads/"

import pandas as pd

def display(combined, csv_path):
    df = pd.read_csv(csv_path)
    for i in range(len(df)): #python replace items in a loop
        for j in range(len(combined)):
            if df["Replacement"][i] == combined[j]:
                combined[j] = df["Display"][i]
    return combined

# %%
#output 1
df = functions.outputs.tdm_make(docs)
df.to_csv(r'{}TDM.csv'.format(save_location))

# %%
for_display = display(combined, replacement_path)

#output 2
functions.outputs.barchart(for_display, save_location)

#output 3
functions.outputs.wc(for_display)
# Out:
# Total>>> [('thalamus', 1049), ('cingulate cortex', 486), ('cuneus', 454), ('precuneus', 413), ('anterior cingulate cortex', 283), ('amygdala', 222), ('posterior cingulate gyrus', 208), ('cerebellar crus', 205), ('hippocampus', 201), ('cerebellum', 139), ('premotor cortex', 136), ('auditory cortex', 128), ('dorsolateral prefrontal cortex', 122), ('lenticular nucleus', 102), ('insular cortex', 86), ('lenticular nucleus pallidum', 85), ('intralaminar thalamus', 84), ('superior temporal gyrus', 82), ('supplementary motor cortex', 79), ('angular gyrus', 76), ('orbitofrontal area', 70), ('orbital inferior frontal gyrus', 68), ('primary motor cortex', 68), ('inferior parietal gyrus', 67), ('caudate nucleus', 65), ('middle frontal gyrus', 65), ('superior frontal gyrus', 57), ('precentral gyrus', 56), ('locus coeruleus', 55), ('postcentral gyrus', 53), ('middle temporal gyrus', 53), ('inferior temporal gyrus', 46), ('ventral tegmental area', 43), ('fusiform gyrus', 41), ('paracentral lobule',
# ...

# %%
total = [('thalamus', 1049), ('cingulate cortex', 486), ('cuneus', 454), ('precuneus', 413), ('anterior cingulate cortex', 283), ('amygdala', 222), ('posterior cingulate gyrus', 208), ('cerebellar crus', 205), ('hippocampus', 201), ('cerebellum', 139), ('premotor cortex', 136), ('auditory cortex', 128), ('dorsolateral prefrontal cortex', 122), ('lenticular nucleus', 102), ('insular cortex', 86), ('lenticular nucleus pallidum', 85), ('intralaminar thalamus', 84), ('superior temporal gyrus', 82), ('supplementary motor cortex', 79), ('angular gyrus', 76), ('orbitofrontal area', 70), ('orbital inferior frontal gyrus', 68), ('primary motor cortex', 68), ('inferior parietal gyrus', 67), ('caudate nucleus', 65), ('middle frontal gyrus', 65), ('superior frontal gyrus', 57), ('precentral gyrus', 56), ('locus coeruleus', 55), ('postcentral gyrus', 53), ('middle temporal gyrus', 53), ('inferior temporal gyrus', 46), ('ventral tegmental area', 43), ('fusiform gyrus', 41), ('paracentral lobule', 35), ('superior parietal lobule', 35), ('retrosplenial cortex', 32), ('anterior cingulate cortex subgenual', 29), ('dorsal anterior cingulate cortex', 29), ('primary somatosensory cortex', 27), ('substantia nigra', 26), ('supramarginal gyrus', 26), ('calcarine fissure', 25), ('anterior temporal lobe', 20), ('ventral entorhinal cortex', 20), ('primary visual cortex', 19), ('raphe nucleus', 17), ('heschls gyrus', 16), ('middle occipital gyrus', 16), ('lenticular nucleus putamen', 12), ('middle cingulate gyrus', 10), ('parahippocampus', 8), ('anterior prefrontal cortex', 8), ('anterior cingulate cortex pregenual', 8), ('paracingulate', 7), ('vermis', 7), ('pulvinar medial thalamus', 6), ('gyrus rectus', 6), ('lingual gyrus', 5), ('rolandic operculum', 5), ('temporopolar area', 5), ('superior occipital gyrus', 4), ('inferior occipital gyrus', 4), ('perirhinal cortex', 3), ('lateral geniculate thalamus', 3), ('medial geniculate thalamus', 3), ('lateral posterior thalamus', 2), ('olfactory cortex', 2), ('ventral anterior cingulate cortex', 2), ('pulvinar inferior thalamus', 2), ('pulvinar anterior thalamus', 2), ('pulvinar lateral thalamus', 2), ('secondary visual cortex', 1), ('associative visual cortex', 1), ('frontal eye fields', 1), ('red nucleus', 1), ('lateral orbital gyrus', 1), ('thalamus anteroventral nucleus', 1)]
len(total)
# Out:
# 78

# %%
total
# Out:
# [('thalamus', 1049),
#  ('cingulate cortex', 486),
#  ('cuneus', 454),
#  ('precuneus', 413),
#  ('anterior cingulate cortex', 283),
#  ('amygdala', 222),
#  ('posterior cingulate gyrus', 208),
#  ('cerebellar crus', 205),
#  ('hippocampus', 201),
#  ('cerebellum', 139),
#  ('premotor cortex', 136),
#  ('auditory cortex', 128),
#  ('dorsolateral prefrontal cortex', 122),
#  ('lenticular nucleus', 102),
#  ('insular cortex', 86),
#  ('lenticular nucleus pallidum', 85),
#  ('intralaminar thalamus', 84),
#  ('superior temporal gyrus', 82),
#  ('supplementary motor cortex', 79),
#  ('angular gyrus', 76),
#  ('orbitofrontal area', 70),
#  ('orbital inferior frontal gyrus', 68),
#  ('primary motor cortex', 68),
#  ('inferior parietal gyrus', 67),
#  ('caudate nucleus', 65),
#  ('middle frontal gyrus', 65),
#  ('superior frontal gyrus', 57),
#  ('precentral gyrus', 56),
#  ('locus coeruleus', 55),
#  ('postcentral gyrus', 53),
#  ('middle temporal gyrus', 53),
# ...
