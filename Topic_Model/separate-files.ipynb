# %%
import shutil
import pandas as pd
import os
import csv

# %%
df = pd.read_csv("/Users/manojarachige/Documents/Coding/BMedScDOC1/BMedScDOC_Scripts/Topic_Model/Results_Abstracts/H_RelevantDocumentTopicMatrix.csv")

# %%
df
# Out:
#       Unnamed: 0          name  \
# 0            240  10652750.txt
# 1            317   1080259.txt
# 2            533   1121820.txt
# 3            668  11530522.txt
# 4            788  11839831.txt
# ...          ...           ...
# 2435       14859   9780743.txt
# 2436       14866   9787050.txt
# 2437       14919   9869326.txt
# 2438       14948   9930900.txt
# 2439       14952    995830.txt
#
#                                          processed_text  word_count  \
# 0     ['rev', 'neurol', 'dec', 'vegetative', 'state'...         123
# 1     ['neurol', 'neurochir', 'pol', 'mayjunparadoxi...          72
# 2     ['vrach', 'delo', 'marcharacteristic', 'disord...          13
# 3     ['prom', 'ekol', 'alter', 'state', 'consciousn...          13
# 4     ['neurology', 'feb', 'minimally', 'conscious',...         179
# ...                                                 ...         ...
# 2435  ['hattatsu', 'sepmri', 'spect', 'mrs', 'findin...         141
# ...

# %%
list = df["name"].tolist()

# %%
for doc in os.listdir("/Users/manojarachige/Documents/Coding/BMedScDOC1/Assets/Abstracts"):
    if doc in list:
        shutil.copy("/Users/manojarachige/Documents/Coding/BMedScDOC1/Assets/Abstracts/" + doc, "/Users/manojarachige/Documents/Coding/BMedScDOC1/Assets/TM_abstracts")
    else:
        shutil.copy("/Users/manojarachige/Documents/Coding/BMedScDOC1/Assets/Abstracts/" + doc, "/Users/manojarachige/Documents/Coding/BMedScDOC1/Assets/TM_ANTI_abstracts")
