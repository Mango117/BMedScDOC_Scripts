# %%
#Search for specific terms within a corpus of texts
#texts used are txt files of pubmed "Disorders of Consciousness" abstracts
#15068 abstracts considered relevant after TM (references already removed)
#Outputs: bar graph of all dictionary terms + BoW of corpus
#Outputs: term document matrix as a csv in downloads

# %%
import functions

# %%
dict_path = "/Users/manojarachige/Documents/Coding/BMedScDOC1/Assets/Inputs/full_dictionary.txt"
corpus_dir = "/Users/manojarachige/Documents/Coding/BMedScDOC1/Assets/Abstracts"
replacement_path = "/Users/manojarachige/Documents/Coding/BMedScDOC1/Assets/Inputs/replacement.csv"

# %%
#define the lists we'll need for outputs

dictionary = []

combined = [] #For pathway 2 - total dictionary list

docs = []

# %%
doc_list = functions.os_level.get_corpus(corpus_dir, "txt")

# %%
print("We have a total of {} abstracts".format(len(doc_list)))
# Out:
# We have a total of 15068 abstracts

# %%
dictionary = functions.os_level.makedict(dict_path)

# %%
def action(i, doc_list, dictionary):
    
    text = maketxt("{}".format(corpus_dir) + "/{}".format(doc_list[i]), replacement_path)
        
    #remove non-dictionary words
    text = rem_dict(dictionary,text) 
        
    #add to Total List for Combined BoW later
    combined.extend(text) 
        
    #check corpus doc again
        
    #add to list of text strings for tdm
    doc_for_tdm = " ".join(text)
    docs.append(doc_for_tdm)
    
    
    
#Create list of words appearing in txt file 
def maketxt(text, csv_path):
    string = ''
    with open(text) as file:
        string = file.read()
        return functions.processing.preprocess(string, csv_path)
    
#Remove words not in the dictionary NOTE: Will find words within words ie. bar within bars
def rem_dict(dictionary, doc):
    new_doc = []
    for i in range(len(doc)):
        for j in range(len(dictionary)):
            if dictionary[j] in doc[i]:
                new_doc.append(dictionary[j])
    return new_doc

# %%
for i in range(len(doc_list)):
            action(i, doc_list, dictionary)

# %%
save_location = "/Users/manojarachige/Downloads/"

import pandas as pd

def display(combined, csv_path):
    df = pd.read_csv(csv_path)
    for i in range(len(df)): #python replace items in a loop
        for j in range(len(combined)):
            if df["Replacement"][i] == combined[j]:
                combined[j] = df["Display"][i]
    return combined

# %%
#output 1
df = functions.outputs.tdm_make(docs)
df.to_csv(r'{}TDM.csv'.format(save_location))

# %%
for_display = display(combined, replacement_path)

#output 2
functions.outputs.barchart(for_display, save_location)

#output 3
functions.outputs.wc(for_display)
# Out:
# Total>>> [('cerebellum', 798), ('thalamus', 569), ('cingulate cortex', 468), ('insular cortex', 258), ('hippocampus', 198), ('default mode network', 119), ('cerebral cortex', 114), ('amygdala', 114), ('dorsolateral prefrontal cortex', 100), ('cuneus', 97), ('precuneus', 90), ('anterior cingulate', 78), ('caudate nucleus', 66), ('posterior cingulate', 57), ('crus', 52), ('orbitofrontal', 45), ('lingual gyrus', 40), ('premotor cortex', 32), ('inferior frontal gyrus', 31), ('primary motor cortex', 25), ('precentral gyrus', 24), ('supplementary motor cortex', 23), ('reticular activating system', 23), ('fusiform gyrus', 20), ('parahippocampus', 19), ('vermis', 17), ('superior temporal gyrus', 17), ('primary visual cortex', 16), ('superior frontal', 16), ('pars opercularis', 16), ('pallidum', 15), ('putamen', 14), ('supramarginal gyrus', 14), ('inferior parietal lobule', 13), ('angular gyrus', 13), ('postcentral gyrus', 12), ('middle frontal gyrus', 11), ('retrosplenial region', 10), ('primary somatosensory cortex', 9), ('piriform cortex', 9), ('inferior temporal gyrus', 8), ('temporal pole', 7), ('paracentral lobule', 6), ('calcarine', 6), ('lenticular nucleus', 6), ('middle temporal gyrus', 6), ('middle occipital gyrus', 6), ('superior parietal lobule', 5), ('orbital gyrus', 5), ('subgenual area', 5), ('middle cingulate', 5), ('primary auditory cortex', 4), ('associative visual cortex', 3), ('lateral orbital gyrus', 3), ('anterior prefrontal cortex', 3), ('olfactory cortex', 2), ('inferior occipital gyrus', 2), ('secondary visual cortex', 2), ('perirhinal cortex', 1), ('primary gustatory cortex', 1), ('posterior orbital gyrus', 1)]
